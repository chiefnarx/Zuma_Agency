# %%
import requests
import pandas as pd
import psycopg2
import json

# %%
url = "https://api.rentcast.io/v1/properties"
headers = {
    "Accept": "application/json",
    "X-Api-Key": "b07dd4766afe474c858ede113ec62d6a"
}

cities = [
    {"city": "Austin", "state": "TX"},
    {"city": "Seattle", "state": "WA"},
    {"city": "Phoenix", "state": "AZ"},
    {"city": "Miami", "state": "FL"}
]

property_limit = 50
all_properties = [] 

for loc in cities:
    print(f"\nFetching properties for {loc['city']}, {loc['state']}...")
    response = requests.get(url, headers=headers, params={**loc, "limit": property_limit})

    if response.status_code == 200:
        data = response.json()
        all_properties.extend(data)  
        for property in data:
            print(property)
    else:
        print(f"API Error {response.status_code}: {response.text}")
# Out:
# Fetching properties for Austin, TX...
# {'id': '7011-W-Parmer-Ln,-Austin,-TX-78729', 'formattedAddress': '7011 W Parmer Ln, Austin, TX 78729', 'addressLine1': '7011 W Parmer Ln', 'addressLine2': None, 'city': 'Austin', 'state': 'TX', 'zipCode': '78729', 'county': 'Williamson', 'latitude': 30.450651, 'longitude': -97.749853, 'propertyType': 'Apartment', 'yearBuilt': 2000}
# {'id': '5200-N-Lamar-Blvd,-Austin,-TX-78751', 'formattedAddress': '5200 N Lamar Blvd, Austin, TX 78751', 'addressLine1': '5200 N Lamar Blvd', 'addressLine2': None, 'city': 'Austin', 'state': 'TX', 'zipCode': '78751', 'county': 'Travis', 'latitude': 30.320159, 'longitude': -97.731593, 'propertyType': 'Single Family', 'bedrooms': 1, 'bathrooms': 1, 'squareFootage': 505, 'yearBuilt': 1984}
# {'id': '1301-W-5th-St,-Austin,-TX-78703', 'formattedAddress': '1301 W 5th St, Austin, TX 78703', 'addressLine1': '1301 W 5th St', 'addressLine2': None, 'city': 'Austin', 'state': 'TX', 'zipCode': '78703', 'county': 'Travis', 'latitude': 30.271746, 'longitude': -97.759877, 'propertyType': 'Apartment', 'bedrooms': 1, 'bathrooms': 1, 'squareFootage': 735, 'yearBuilt': 2019}
# {'id': '1044-Camino-Ln,-Costa,-Austin,-TX-78752', 'formattedAddress': '1044 Camino Ln, Costa, Austin, TX 78752', 'addressLine1': '1044 Camino Ln', 'addressLine2': 'Costa', 'city': 'Austin', 'state': 'TX', 'zipCode': '78752', 'county': 'Travis', 'latitude': 30.32526, 'longitude': -97.69927, 'propertyType': 'Apartment', 'yearBuilt': 1984}
# {'id': '800-W-38th-St,-Austin,-TX-78705', 'formattedAddress': '800 W 38th St, Austin, TX 78705', 'addressLine1': '800 W 38th St', 'addressLine2': None, 'city': 'Austin', 'state': 'TX', 'zipCode': '78705', 'county': 'Travis', 'latitude': 30.304715, 'longitude': -97.741423, 'propertyType': 'Apartment', 'bedrooms': 2, 'bathrooms': 2, 'yearBuilt': 1997}
# {'id': '8801-N-Fm-620-Rd,-Austin,-TX-78726', 'formattedAddress': '8801 N Fm 620 Rd, Austin, TX 78726', 'addressLine1': '8801 N Fm 620 Rd', 'addressLine2': None, 'city': 'Austin', 'state': 'TX', 'zipCode': '78726', 'county': 'Travis', 'latitude': 30.42695, 'longitude': -97.84242, 'propertyType': 'Apartment', 'yearBuilt': 1998, 'features': {'unitCount': 300}}
# {'id': '2104-E-Anderson-Ln,-Austin,-TX-78752', 'formattedAddress': '2104 E Anderson Ln, Austin, TX 78752', 'addressLine1': '2104 E Anderson Ln', 'addressLine2': None, 'city': 'Austin', 'state': 'TX', 'zipCode': '78752', 'county': 'Travis', 'latitude': 30.331529, 'longitude': -97.677648, 'propertyType': 'Apartment', 'bedrooms': 1, 'bathrooms': 1, 'yearBuilt': 1984, 'features': {'unitCount': 290}, 'taxAssessments': {'2013': {'year': 2013, 'value': 5500000, 'land': 1336968, 'improvements': 4163032}, '2014': {'year': 2014, 'value': 5700000, 'land': 1336968, 'improvements': 4363032}, '2016': {'year': 2016, 'value': 6270000, 'land': 1336968, 'improvements': 4933032}, '2017': {'year': 2017, 'value': 7000000, 'land': 2673936, 'improvements': 4326064}, '2018': {'year': 2018, 'value': 7123452, 'land': 2673936, 'improvements': 4449516}, '2019': {'year': 2019, 'value': 7480000, 'land': 2673936, 'improvements': 4806064}, '2020': {'year': 2020, 'value': 7854716, 'land': 2673936, 'improvements': 5180780}, '2021': {'year': 2021, 'value': 8981812, 'land': 4278298, 'improvements': 4703514}, '2022': {'year': 2022, 'value': 10915100, 'land': 4278298, 'improvements': 6636802}, '2023': {'year': 2023, 'value': 11926140, 'land': 4278298, 'improvements': 7647842}}, 'propertyTaxes': {'2013': {'year': 2013, 'total': 266325}, '2014': {'year': 2014, 'total': 152232}, '2016': {'year': 2016, 'total': 301891}, '2017': {'year': 2017, 'total': 266783}, '2018': {'year': 2018, 'total': 278928}, '2019': {'year': 2019, 'total': 291529}, '2020': {'year': 2020, 'total': 324680}, '2021': {'year': 2021, 'total': 400511}, '2022': {'year': 2022, 'total': 403499}, '2023': {'year': 2023, 'total': 345303}}}
# {'id': '12430-Metric-Blvd,-Austin,-TX-78758', 'formattedAddress': '12430 Metric Blvd, Austin, TX 78758', 'addressLine1': '12430 Metric Blvd', 'addressLine2': None, 'city': 'Austin', 'state': 'TX', 'zipCode': '78758', 'county': 'Travis', 'latitude': 30.41274, 'longitude': -97.692939, 'propertyType': 'Apartment', 'bedrooms': 1, 'bathrooms': 1, 'squareFootage': 664, 'yearBuilt': 2006}
# {'id': '6500-Champion-Grandview-Way,-Austin,-TX-78750', 'formattedAddress': '6500 Champion Grandview Way, Austin, TX 78750', 'addressLine1': '6500 Champion Grandview Way', 'addressLine2': None, 'city': 'Austin', 'state': 'TX', 'zipCode': '78750', 'county': 'Travis', 'latitude': 30.3642, 'longitude': -97.79181, 'propertyType': 'Apartment', 'bedrooms': 1, 'bathrooms': 1, 'squareFootage': 950, 'yearBuilt': 2004}
# {'id': '2402-San-Gabriel-St,-Austin,-TX-78705', 'formattedAddress': '2402 San Gabriel St, Austin, TX 78705', 'addressLine1': '2402 San Gabriel St', 'addressLine2': None, 'city': 'Austin', 'state': 'TX', 'zipCode': '78705', 'county': 'Travis', 'latitude': 30.288448, 'longitude': -97.747951, 'propertyType': 'Apartment'}
# {'id': '1621-E-6th-St,-Austin,-TX-78702', 'formattedAddress': '1621 E 6th St, Austin, TX 78702', 'addressLine1': '1621 E 6th St', 'addressLine2': None, 'city': 'Austin', 'state': 'TX', 'zipCode': '78702', 'county': 'Travis', 'latitude': 30.262248, 'longitude': -97.726008, 'propertyType': 'Apartment', 'bedrooms': 2, 'bathrooms': 2, 'squareFootage': 704, 'lotSize': 43560, 'yearBuilt': 2018}
# {'id': '1911-Willow-Creek-Dr,-Austin,-TX-78741', 'formattedAddress': '1911 Willow Creek Dr, Austin, TX 78741', 'addressLine1': '1911 Willow Creek Dr', 'addressLine2': None, 'city': 'Austin', 'state': 'TX', 'zipCode': '78741', 'county': 'Travis', 'latitude': 30.23256, 'longitude': -97.72886, 'propertyType': 'Apartment', 'bedrooms': 1, 'bathrooms': 1, 'squareFootage': 860, 'yearBuilt': 1969}
# {'id': '1611-W-5th-St,-Austin,-TX-78703', 'formattedAddress': '1611 W 5th St, Austin, TX 78703', 'addressLine1': '1611 W 5th St', 'addressLine2': None, 'city': 'Austin', 'state': 'TX', 'zipCode': '78703', 'county': 'Travis', 'latitude': 30.273858, 'longitude': -97.764246, 'propertyType': 'Apartment', 'bedrooms': 2, 'bathrooms': 2, 'squareFootage': 1131, 'yearBuilt': 2009}
# {'id': '1720-W-Wells-Branch-Pkwy,-Austin,-TX-78728', 'formattedAddress': '1720 W Wells Branch Pkwy, Austin, TX 78728', 'addressLine1': '1720 W Wells Branch Pkwy', 'addressLine2': None, 'city': 'Austin', 'state': 'TX', 'zipCode': '78728', 'county': 'Travis County', 'latitude': 30.440369, 'longitude': -97.672445, 'propertyType': 'Apartment', 'yearBuilt': 1996}
# {'id': '13145-N-Hwy,-183,-Austin,-TX-78750', 'formattedAddress': '13145 N Hwy, 183, Austin, TX 78750', 'addressLine1': '13145 N Hwy', 'addressLine2': '183', 'city': 'Austin', 'state': 'TX', 'zipCode': '78750', 'county': 'Williamson County', 'latitude': 30.442044, 'longitude': -97.778631, 'propertyType': 'Apartment', 'bedrooms': 1, 'bathrooms': 1, 'squareFootage': 709, 'yearBuilt': 2007}
# {'id': '6607-Brodie-Ln,-Austin,-TX-78745', 'formattedAddress': '6607 Brodie Ln, Austin, TX 78745', 'addressLine1': '6607 Brodie Ln', 'addressLine2': None, 'city': 'Austin', 'state': 'TX', 'zipCode': '78745', 'county': 'Travis', 'latitude': 30.215883, 'longitude': -97.825396, 'propertyType': 'Apartment', 'yearBuilt': 1997}
# {'id': '3816-S-Lamar-Blvd,-Austin,-TX-78704', 'formattedAddress': '3816 S Lamar Blvd, Austin, TX 78704', 'addressLine1': '3816 S Lamar Blvd', 'addressLine2': None, 'city': 'Austin', 'state': 'TX', 'zipCode': '78704', 'county': 'Travis', 'latitude': 30.239108, 'longitude': -97.79131, 'propertyType': 'Apartment', 'bedrooms': 1, 'bathrooms': 1, 'yearBuilt': 1984}
# {'id': '1507-Kinney-Ave,-Austin,-TX-78704', 'formattedAddress': '1507 Kinney Ave, Austin, TX 78704', 'addressLine1': '1507 Kinney Ave', 'addressLine2': None, 'city': 'Austin', 'state': 'TX', 'zipCode': '78704', 'county': 'Travis County', 'latitude': 30.253431, 'longitude': -97.766611, 'propertyType': 'Apartment', 'bathrooms': 1, 'yearBuilt': 1982}
# {'id': '1034-Clayton-Ln,-Austin,-TX-78723', 'formattedAddress': '1034 Clayton Ln, Austin, TX 78723', 'addressLine1': '1034 Clayton Ln', 'addressLine2': None, 'city': 'Austin', 'state': 'TX', 'zipCode': '78723', 'county': 'Travis', 'latitude': 30.31971, 'longitude': -97.7031, 'propertyType': 'Single Family', 'bathrooms': 2, 'yearBuilt': 1998}
# {'id': '1403-Norwalk-Ln,-Austin,-TX-78703', 'formattedAddress': '1403 Norwalk Ln, Austin, TX 78703', 'addressLine1': '1403 Norwalk Ln', 'addressLine2': None, 'city': 'Austin', 'state': 'TX', 'zipCode': '78703', 'county': 'Travis', 'latitude': 30.28921, 'longitude': -97.7714, 'propertyType': 'Apartment', 'bedrooms': 2, 'bathrooms': 2, 'yearBuilt': 1963}
# {'id': '811-E-11th-St,-Austin,-TX-78702', 'formattedAddress': '811 E 11th St, Austin, TX 78702', 'addressLine1': '811 E 11th St', 'addressLine2': None, 'city': 'Austin', 'state': 'TX', 'zipCode': '78702', 'county': 'Travis', 'latitude': 30.26943, 'longitude': -97.73204, 'propertyType': 'Apartment', 'bedrooms': 1, 'bathrooms': 1, 'squareFootage': 675, 'yearBuilt': 2013}
# {'id': '2819-Foster-Ln,-Austin,-TX-78757', 'formattedAddress': '2819 Foster Ln, Austin, TX 78757', 'addressLine1': '2819 Foster Ln', 'addressLine2': None, 'city': 'Austin', 'state': 'TX', 'zipCode': '78757', 'county': 'Travis County', 'latitude': 30.356331, 'longitude': -97.73818, 'propertyType': 'Apartment', 'yearBuilt': 1979}
# {'id': '1511-Faro-Dr,-Austin,-TX-78741', 'formattedAddress': '1511 Faro Dr, Austin, TX 78741', 'addressLine1': '1511 Faro Dr', 'addressLine2': None, 'city': 'Austin', 'state': 'TX', 'zipCode': '78741', 'county': 'Travis County', 'latitude': 30.235227, 'longitude': -97.712617, 'propertyType': 'Apartment', 'bathrooms': 1, 'yearBuilt': 1984}
# {'id': '1908-W-Loop,-Apt-A,-Austin,-TX-78758', 'formattedAddress': '1908 W Loop, Apt A, Austin, TX 78758', 'addressLine1': '1908 W Loop', 'addressLine2': 'Apt A', 'city': 'Austin', 'state': 'TX', 'zipCode': '78758', 'county': 'Travis', 'latitude': 30.372162, 'longitude': -97.718242, 'propertyType': 'Multi-Family', 'bedrooms': 2, 'bathrooms': 1, 'squareFootage': 977}
# {'id': '6263-Mcneil-Dr,-Austin,-TX-78729', 'formattedAddress': '6263 Mcneil Dr, Austin, TX 78729', 'addressLine1': '6263 Mcneil Dr', 'addressLine2': None, 'city': 'Austin', 'state': 'TX', 'zipCode': '78729', 'county': 'Travis', 'latitude': 30.440315, 'longitude': -97.747084, 'propertyType': 'Apartment', 'bedrooms': 1, 'bathrooms': 1.5, 'squareFootage': 697, 'yearBuilt': 1996}
# {'id': '8000-Decker-Ln,-Austin,-TX-78724', 'formattedAddress': '8000 Decker Ln, Austin, TX 78724', 'addressLine1': '8000 Decker Ln', 'addressLine2': None, 'city': 'Austin', 'state': 'TX', 'zipCode': '78724', 'county': 'Travis', 'latitude': 30.308724, 'longitude': -97.624002, 'propertyType': 'Apartment', 'yearBuilt': 2004}
# {'id': '1810-Adina-St,-Unit-B,-Austin,-TX-78721', 'formattedAddress': '1810 Adina St, Unit B, Austin, TX 78721', 'addressLine1': '1810 Adina St', 'addressLine2': 'Unit B', 'city': 'Austin', 'state': 'TX', 'zipCode': '78721', 'county': 'Travis County', 'latitude': 30.283132, 'longitude': -97.679825, 'propertyType': 'Multi-Family', 'bedrooms': 3, 'bathrooms': 2.5, 'squareFootage': 1495}
# {'id': '8312-Fathom-Cir,-Austin,-TX-78750', 'formattedAddress': '8312 Fathom Cir, Austin, TX 78750', 'addressLine1': '8312 Fathom Cir', 'addressLine2': None, 'city': 'Austin', 'state': 'TX', 'zipCode': '78750', 'county': 'Williamson', 'latitude': 30.436356, 'longitude': -97.7768, 'propertyType': 'Apartment', 'yearBuilt': 1984}
# {'id': '7224-Northeast-Dr,-Austin,-TX-78723', 'formattedAddress': '7224 Northeast Dr, Austin, TX 78723', 'addressLine1': '7224 Northeast Dr', 'addressLine2': None, 'city': 'Austin', 'state': 'TX', 'zipCode': '78723', 'county': 'Travis County', 'latitude': 30.321055, 'longitude': -97.680679, 'propertyType': 'Apartment', 'yearBuilt': 1972}
# {'id': '8001-S-Ih,---35,-Austin,-TX-78744', 'formattedAddress': '8001 S Ih, # 35, Austin, TX 78744', 'addressLine1': '8001 S Ih', 'addressLine2': '# 35', 'city': 'Austin', 'state': 'TX', 'zipCode': '78744', 'county': 'Travis County', 'latitude': 30.174784, 'longitude': -97.775327, 'propertyType': 'Apartment', 'yearBuilt': 2014}
# {'id': '9501-N-Fm-620-Rd,-Austin,-TX-78726', 'formattedAddress': '9501 N Fm 620 Rd, Austin, TX 78726', 'addressLine1': '9501 N Fm 620 Rd', 'addressLine2': None, 'city': 'Austin', 'state': 'TX', 'zipCode': '78726', 'county': 'Travis', 'latitude': 30.43486, 'longitude': -97.83915, 'propertyType': 'Apartment', 'bedrooms': 1, 'bathrooms': 1, 'squareFootage': 909, 'yearBuilt': 2006, 'features': {'unitCount': 336}}
# {'id': '500-E-Anderson-Ln,-Austin,-TX-78752', 'formattedAddress': '500 E Anderson Ln, Austin, TX 78752', 'addressLine1': '500 E Anderson Ln', 'addressLine2': None, 'city': 'Austin', 'state': 'TX', 'zipCode': '78752', 'county': 'Travis', 'latitude': 30.34206, 'longitude': -97.70144, 'propertyType': 'Apartment', 'yearBuilt': 1967}
# {'id': '9617-Great-Hills-Trl,-Austin,-TX-78759', 'formattedAddress': '9617 Great Hills Trl, Austin, TX 78759', 'addressLine1': '9617 Great Hills Trl', 'addressLine2': None, 'city': 'Austin', 'state': 'TX', 'zipCode': '78759', 'county': 'Travis', 'latitude': 30.393533, 'longitude': -97.753775, 'propertyType': 'Apartment', 'yearBuilt': 1984}
# {'id': '625-E-Stassney-Ln,-Austin,-TX-78745', 'formattedAddress': '625 E Stassney Ln, Austin, TX 78745', 'addressLine1': '625 E Stassney Ln', 'addressLine2': None, 'city': 'Austin', 'state': 'TX', 'zipCode': '78745', 'county': 'Travis', 'latitude': 30.20068, 'longitude': -97.76971, 'propertyType': 'Apartment', 'yearBuilt': 2009}
# {'id': '3621-W-Slaughter-Ln,-Austin,-TX-78749', 'formattedAddress': '3621 W Slaughter Ln, Austin, TX 78749', 'addressLine1': '3621 W Slaughter Ln', 'addressLine2': None, 'city': 'Austin', 'state': 'TX', 'zipCode': '78749', 'county': 'Travis', 'latitude': 30.18414, 'longitude': -97.85339, 'propertyType': 'Apartment', 'bedrooms': 1, 'bathrooms': 1, 'squareFootage': 815, 'yearBuilt': 2012}
# {'id': '8805-N-Plaza-Dr,-Austin,-TX-78753', 'formattedAddress': '8805 N Plaza Dr, Austin, TX 78753', 'addressLine1': '8805 N Plaza Dr', 'addressLine2': None, 'city': 'Austin', 'state': 'TX', 'zipCode': '78753', 'county': 'Travis', 'latitude': 30.34965, 'longitude': -97.68629, 'propertyType': 'Apartment', 'yearBuilt': 1978, 'features': {'unitCount': 352}}
# {'id': '111-Sandra-Muraida-Way,-Austin,-TX-78703', 'formattedAddress': '111 Sandra Muraida Way, Austin, TX 78703', 'addressLine1': '111 Sandra Muraida Way', 'addressLine2': None, 'city': 'Austin', 'state': 'TX', 'zipCode': '78703', 'county': 'Travis', 'latitude': 30.267449, 'longitude': -97.754759, 'propertyType': 'Apartment', 'bedrooms': 1, 'bathrooms': 1.5, 'squareFootage': 1079, 'yearBuilt': 2013}
# {'id': '1300-Pleasant-Valley-Rd-S,-Austin,-TX-78741', 'formattedAddress': '1300 Pleasant Valley Rd S, Austin, TX 78741', 'addressLine1': '1300 Pleasant Valley Rd S', 'addressLine2': None, 'city': 'Austin', 'state': 'TX', 'zipCode': '78741', 'county': 'Travis County', 'latitude': 30.24047, 'longitude': -97.719682, 'propertyType': 'Apartment', 'yearBuilt': 1972}
# {'id': '10600-Jollyville-Rd,-Austin,-TX-78759', 'formattedAddress': '10600 Jollyville Rd, Austin, TX 78759', 'addressLine1': '10600 Jollyville Rd', 'addressLine2': None, 'city': 'Austin', 'state': 'TX', 'zipCode': '78759', 'county': 'Travis', 'latitude': 30.399719, 'longitude': -97.749875, 'propertyType': 'Apartment', 'bedrooms': 1, 'bathrooms': 1, 'squareFootage': 618, 'yearBuilt': 2017}
# {'id': '460-Bastrop-Hwy-S,-Austin,-TX-78741', 'formattedAddress': '460 Bastrop Hwy S, Austin, TX 78741', 'addressLine1': '460 Bastrop Hwy S', 'addressLine2': None, 'city': 'Austin', 'state': 'TX', 'zipCode': '78741', 'county': 'Travis', 'latitude': 30.237778, 'longitude': -97.688568, 'propertyType': 'Apartment', 'bedrooms': 3, 'bathrooms': 2, 'squareFootage': 981, 'yearBuilt': 2019}
# {'id': '7000-E-Ben-White-Blvd,-Austin,-TX-78741', 'formattedAddress': '7000 E Ben White Blvd, Austin, TX 78741', 'addressLine1': '7000 E Ben White Blvd', 'addressLine2': None, 'city': 'Austin', 'state': 'TX', 'zipCode': '78741', 'county': 'Travis', 'latitude': 30.217479, 'longitude': -97.702228, 'propertyType': 'Apartment', 'bedrooms': 2, 'bathrooms': 2, 'yearBuilt': 2016}
# {'id': '1003-Justin-Ln,-Austin,-TX-78757', 'formattedAddress': '1003 Justin Ln, Austin, TX 78757', 'addressLine1': '1003 Justin Ln', 'addressLine2': None, 'city': 'Austin', 'state': 'TX', 'zipCode': '78757', 'county': 'Travis', 'latitude': 30.337039, 'longitude': -97.722252, 'propertyType': 'Apartment', 'yearBuilt': 1984}
# {'id': '300-West-Ave,-Austin,-TX-78701', 'formattedAddress': '300 West Ave, Austin, TX 78701', 'addressLine1': '300 West Ave', 'addressLine2': None, 'city': 'Austin', 'state': 'TX', 'zipCode': '78701', 'county': 'Travis', 'latitude': 30.2686, 'longitude': -97.75291, 'propertyType': 'Apartment', 'bathrooms': 1, 'yearBuilt': 2001, 'features': {'unitCount': 239}}
# {'id': '2016-Park-Bend-Dr,-Austin,-TX-78758', 'formattedAddress': '2016 Park Bend Dr, Austin, TX 78758', 'addressLine1': '2016 Park Bend Dr', 'addressLine2': None, 'city': 'Austin', 'state': 'TX', 'zipCode': '78758', 'county': 'Travis', 'latitude': 30.408332, 'longitude': -97.698735, 'propertyType': 'Multi-Family', 'squareFootage': 184900, 'lotSize': 475240, 'yearBuilt': 1985, 'assessorID': '262627', 'legalDescription': 'LOT 1 BLK A VILLAGE AT WALNUT CREEK PHS 2 SEC 12', 'subdivision': 'VILLAGE AT WALNUT CREEK PH 2', 'features': {'architectureType': 'Multi-Unit Building', 'fireplace': True, 'floorCount': 3, 'foundationType': 'Slab / Mat / Raft', 'roofType': 'Composition Shingle', 'unitCount': 2}, 'taxAssessments': {'2018': {'year': 2018, 'value': 33465000, 'land': 3801920, 'improvements': 29663080}}, 'propertyTaxes': {'2018': {'year': 2018, 'total': 735065}}, 'owner': {'names': ['TWAREL LLC'], 'mailingAddress': {'id': '540-Madison-Ave,-FL-26,-New-York,-NY-10022', 'addressLine1': '540 Madison Ave', 'addressLine2': 'FL 26', 'city': 'New York', 'state': 'NY', 'zipCode': '10022'}}, 'ownerOccupied': False}
# {'id': '6600-Ed-Bluestein-Blvd,-Austin,-TX-78723', 'formattedAddress': '6600 Ed Bluestein Blvd, Austin, TX 78723', 'addressLine1': '6600 Ed Bluestein Blvd', 'addressLine2': None, 'city': 'Austin', 'state': 'TX', 'zipCode': '78723', 'county': 'Travis', 'latitude': 30.305748, 'longitude': -97.66245, 'propertyType': 'Apartment', 'bedrooms': 1, 'bathrooms': 1, 'squareFootage': 500, 'yearBuilt': 1985}
# {'id': '1200-E-Parmer-Ln,-Austin,-TX-78753', 'formattedAddress': '1200 E Parmer Ln, Austin, TX 78753', 'addressLine1': '1200 E Parmer Ln', 'addressLine2': None, 'city': 'Austin', 'state': 'TX', 'zipCode': '78753', 'county': 'Travis', 'latitude': 30.396078, 'longitude': -97.652516, 'propertyType': 'Apartment', 'yearBuilt': 2013}
# {'id': '700-Hearn-St,-Austin,-TX-78703', 'formattedAddress': '700 Hearn St, Austin, TX 78703', 'addressLine1': '700 Hearn St', 'addressLine2': None, 'city': 'Austin', 'state': 'TX', 'zipCode': '78703', 'county': 'Travis', 'latitude': 30.280987, 'longitude': -97.771896, 'propertyType': 'Apartment', 'bedrooms': 1, 'bathrooms': 1, 'yearBuilt': 1974}
# {'id': '7601-Rialto-Blvd,-Austin,-TX-78735', 'formattedAddress': '7601 Rialto Blvd, Austin, TX 78735', 'addressLine1': '7601 Rialto Blvd', 'addressLine2': None, 'city': 'Austin', 'state': 'TX', 'zipCode': '78735', 'county': 'Travis', 'latitude': 30.25294, 'longitude': -97.87262, 'propertyType': 'Apartment', 'yearBuilt': 2002}
# {'id': '15510-Ranch-Road-620-Rd,-Austin,-TX-78717', 'formattedAddress': '15510 Ranch Road 620 Rd, Austin, TX 78717', 'addressLine1': '15510 Ranch Road 620 Rd', 'addressLine2': None, 'city': 'Austin', 'state': 'TX', 'zipCode': '78717', 'county': 'Williamson County', 'latitude': 30.485601, 'longitude': -97.736289, 'propertyType': 'Apartment', 'yearBuilt': 2008}
# {'id': '8701-Bluffstone-Cv,-Austin,-TX-78759', 'formattedAddress': '8701 Bluffstone Cv, Austin, TX 78759', 'addressLine1': '8701 Bluffstone Cv', 'addressLine2': None, 'city': 'Austin', 'state': 'TX', 'zipCode': '78759', 'county': 'Travis', 'latitude': 30.390953, 'longitude': -97.763931, 'propertyType': 'Apartment', 'yearBuilt': 1998}
#
# Fetching properties for Seattle, WA...
# {'id': '11060-Ne-2nd-Ave,-Seattle,-WA-98125', 'formattedAddress': '11060 Ne 2nd Ave, Seattle, WA 98125', 'addressLine1': '11060 Ne 2nd Ave', 'addressLine2': None, 'city': 'Seattle', 'state': 'WA', 'zipCode': '98125', 'county': 'King County', 'latitude': 47.709573, 'longitude': -122.327355, 'propertyType': 'Apartment', 'bathrooms': 1, 'yearBuilt': 1954}
# {'id': '1251-Taylor-Ave-N,-Seattle,-WA-98109', 'formattedAddress': '1251 Taylor Ave N, Seattle, WA 98109', 'addressLine1': '1251 Taylor Ave N', 'addressLine2': None, 'city': 'Seattle', 'state': 'WA', 'zipCode': '98109', 'county': 'King', 'latitude': 47.631123, 'longitude': -122.346637, 'propertyType': 'Apartment', 'bedrooms': 2, 'bathrooms': 1, 'yearBuilt': 1978}
# {'id': '1321-E-John-St,-Seattle,-WA-98102', 'formattedAddress': '1321 E John St, Seattle, WA 98102', 'addressLine1': '1321 E John St', 'addressLine2': None, 'city': 'Seattle', 'state': 'WA', 'zipCode': '98102', 'county': 'King', 'latitude': 47.619789, 'longitude': -122.31469, 'propertyType': 'Apartment', 'bedrooms': 1, 'bathrooms': 1, 'yearBuilt': 2014}
# {'id': '5398-Russell-Ave-NW,-Seattle,-WA-98107', 'formattedAddress': '5398 Russell Ave NW, Seattle, WA 98107', 'addressLine1': '5398 Russell Ave NW', 'addressLine2': None, 'city': 'Seattle', 'state': 'WA', 'zipCode': '98107', 'county': 'King', 'latitude': 47.66798, 'longitude': -122.38137, 'propertyType': 'Apartment', 'bedrooms': 2, 'bathrooms': 2, 'squareFootage': 942, 'yearBuilt': 2015}
# {'id': '10711-8th-Ave-NE,-Seattle,-WA-98125', 'formattedAddress': '10711 8th Ave NE, Seattle, WA 98125', 'addressLine1': '10711 8th Ave NE', 'addressLine2': None, 'city': 'Seattle', 'state': 'WA', 'zipCode': '98125', 'county': 'King', 'latitude': 47.707008, 'longitude': -122.321083, 'propertyType': 'Apartment', 'bedrooms': 1, 'bathrooms': 1, 'yearBuilt': 2019}
# {'id': '600-W-Olympic-Pl,-Seattle,-WA-98119', 'formattedAddress': '600 W Olympic Pl, Seattle, WA 98119', 'addressLine1': '600 W Olympic Pl', 'addressLine2': None, 'city': 'Seattle', 'state': 'WA', 'zipCode': '98119', 'county': 'King', 'latitude': 47.62764, 'longitude': -122.365128, 'propertyType': 'Apartment', 'bedrooms': 2, 'bathrooms': 1, 'squareFootage': 900, 'yearBuilt': 1956}
# {'id': '4100-Sw-Edmunds-St,-Seattle,-WA-98116', 'formattedAddress': '4100 Sw Edmunds St, Seattle, WA 98116', 'addressLine1': '4100 Sw Edmunds St', 'addressLine2': None, 'city': 'Seattle', 'state': 'WA', 'zipCode': '98116', 'county': 'King', 'latitude': 47.56021, 'longitude': -122.38442, 'propertyType': 'Apartment', 'yearBuilt': 1987}
# {'id': '2615-25th-Ave-S,-Seattle,-WA-98144', 'formattedAddress': '2615 25th Ave S, Seattle, WA 98144', 'addressLine1': '2615 25th Ave S', 'addressLine2': None, 'city': 'Seattle', 'state': 'WA', 'zipCode': '98144', 'county': 'King County', 'latitude': 47.579515, 'longitude': -122.300585, 'propertyType': 'Apartment', 'bedrooms': 2, 'bathrooms': 2, 'squareFootage': 1005}
# {'id': '1430-2nd-Ave,-Seattle,-WA-98101', 'formattedAddress': '1430 2nd Ave, Seattle, WA 98101', 'addressLine1': '1430 2nd Ave', 'addressLine2': None, 'city': 'Seattle', 'state': 'WA', 'zipCode': '98101', 'county': 'King', 'latitude': 47.609133, 'longitude': -122.3383, 'propertyType': 'Apartment', 'bedrooms': 2, 'bathrooms': 2, 'squareFootage': 1169, 'yearBuilt': 2018}
# {'id': '14200-Linden-Ave-N,-Seattle,-WA-98133', 'formattedAddress': '14200 Linden Ave N, Seattle, WA 98133', 'addressLine1': '14200 Linden Ave N', 'addressLine2': None, 'city': 'Seattle', 'state': 'WA', 'zipCode': '98133', 'county': 'King', 'latitude': 47.73198, 'longitude': -122.34751, 'propertyType': 'Apartment', 'yearBuilt': 2009}
# {'id': '1850-N-34th-St,-Seattle,-WA-98103', 'formattedAddress': '1850 N 34th St, Seattle, WA 98103', 'addressLine1': '1850 N 34th St', 'addressLine2': None, 'city': 'Seattle', 'state': 'WA', 'zipCode': '98103', 'county': 'King', 'latitude': 47.64823, 'longitude': -122.33596, 'propertyType': 'Apartment', 'yearBuilt': 2016}
# {'id': '403-Dexter-Ave-N,-Seattle,-WA-98109', 'formattedAddress': '403 Dexter Ave N, Seattle, WA 98109', 'addressLine1': '403 Dexter Ave N', 'addressLine2': None, 'city': 'Seattle', 'state': 'WA', 'zipCode': '98109', 'county': 'King', 'latitude': 47.622433, 'longitude': -122.342766, 'propertyType': 'Apartment', 'bedrooms': 1, 'bathrooms': 1, 'squareFootage': 508, 'yearBuilt': 2019}
# {'id': '10711-Meridian-Ave-N,-Seattle,-WA-98133', 'formattedAddress': '10711 Meridian Ave N, Seattle, WA 98133', 'addressLine1': '10711 Meridian Ave N', 'addressLine2': None, 'city': 'Seattle', 'state': 'WA', 'zipCode': '98133', 'county': 'King', 'latitude': 47.70734, 'longitude': -122.334625, 'propertyType': 'Apartment', 'bedrooms': 1, 'bathrooms': 1, 'yearBuilt': 1987}
# {'id': '10541-Stone-Ave-N,-Seattle,-WA-98133', 'formattedAddress': '10541 Stone Ave N, Seattle, WA 98133', 'addressLine1': '10541 Stone Ave N', 'addressLine2': None, 'city': 'Seattle', 'state': 'WA', 'zipCode': '98133', 'county': 'King County', 'latitude': 47.706243, 'longitude': -122.342417, 'propertyType': 'Apartment', 'bedrooms': 1, 'bathrooms': 1, 'yearBuilt': 1984}
# {'id': '8500-20th-Ave-NE,-Seattle,-WA-98115', 'formattedAddress': '8500 20th Ave NE, Seattle, WA 98115', 'addressLine1': '8500 20th Ave NE', 'addressLine2': None, 'city': 'Seattle', 'state': 'WA', 'zipCode': '98115', 'county': 'King', 'latitude': 47.690533, 'longitude': -122.306473, 'propertyType': 'Apartment', 'bedrooms': 0, 'bathrooms': 1, 'yearBuilt': 2018}
# {'id': '15135-Stone-Ln-N,-Seattle,-WA-98133', 'formattedAddress': '15135 Stone Ln N, Seattle, WA 98133', 'addressLine1': '15135 Stone Ln N', 'addressLine2': None, 'city': 'Seattle', 'state': 'WA', 'zipCode': '98133', 'county': 'King County', 'latitude': 47.737753, 'longitude': -122.34216, 'propertyType': 'Apartment', 'bedrooms': 1, 'bathrooms': 1, 'yearBuilt': 1983}
# {'id': '101-6th-Ave-S,-Seattle,-WA-98104', 'formattedAddress': '101 6th Ave S, Seattle, WA 98104', 'addressLine1': '101 6th Ave S', 'addressLine2': None, 'city': 'Seattle', 'state': 'WA', 'zipCode': '98104', 'county': 'King', 'latitude': 47.601379, 'longitude': -122.326637, 'propertyType': 'Apartment', 'bedrooms': 2, 'bathrooms': 2, 'squareFootage': 863, 'yearBuilt': 2019}
# {'id': '105-Warren-Ave-N,-Seattle,-WA-98109', 'formattedAddress': '105 Warren Ave N, Seattle, WA 98109', 'addressLine1': '105 Warren Ave N', 'addressLine2': None, 'city': 'Seattle', 'state': 'WA', 'zipCode': '98109', 'county': 'King', 'latitude': 47.61879, 'longitude': -122.35451, 'propertyType': 'Apartment', 'bedrooms': 1, 'bathrooms': 1, 'squareFootage': 464, 'yearBuilt': 2017}
# {'id': '2525-14th-Ave-S,-Seattle,-WA-98144', 'formattedAddress': '2525 14th Ave S, Seattle, WA 98144', 'addressLine1': '2525 14th Ave S', 'addressLine2': None, 'city': 'Seattle', 'state': 'WA', 'zipCode': '98144', 'county': 'King County', 'latitude': 47.580246, 'longitude': -122.315423, 'propertyType': 'Apartment', 'bedrooms': 0, 'bathrooms': 1, 'yearBuilt': 1918}
# {'id': '2641-42nd-Ave-SW,-Seattle,-WA-98116', 'formattedAddress': '2641 42nd Ave SW, Seattle, WA 98116', 'addressLine1': '2641 42nd Ave SW', 'addressLine2': None, 'city': 'Seattle', 'state': 'WA', 'zipCode': '98116', 'county': 'King', 'latitude': 47.57981, 'longitude': -122.38554, 'propertyType': 'Apartment', 'bathrooms': 1, 'yearBuilt': 2012}
# {'id': '337-Ne-103rd-St,-Seattle,-WA-98125', 'formattedAddress': '337 Ne 103rd St, Seattle, WA 98125', 'addressLine1': '337 Ne 103rd St', 'addressLine2': None, 'city': 'Seattle', 'state': 'WA', 'zipCode': '98125', 'county': 'King', 'latitude': 47.70219, 'longitude': -122.325, 'propertyType': 'Apartment', 'bathrooms': 1, 'yearBuilt': 2009}
# {'id': 'Union-St-@-23rd-Ave,-Seattle,-WA-98122', 'formattedAddress': 'Union St @ 23rd Ave, Seattle, WA 98122', 'addressLine1': 'Union St @ 23rd Ave', 'addressLine2': None, 'city': 'Seattle', 'state': 'WA', 'zipCode': '98122', 'county': 'King County', 'latitude': 47.61332, 'longitude': -122.30319, 'propertyType': 'Apartment', 'bathrooms': 1, 'yearBuilt': 2018}
# {'id': '527-Eastlake-Ave-E,-Seattle,-WA-98109', 'formattedAddress': '527 Eastlake Ave E, Seattle, WA 98109', 'addressLine1': '527 Eastlake Ave E', 'addressLine2': None, 'city': 'Seattle', 'state': 'WA', 'zipCode': '98109', 'county': 'King', 'latitude': 47.623976, 'longitude': -122.329526, 'propertyType': 'Apartment', 'bedrooms': 1, 'bathrooms': 1, 'yearBuilt': 1915}
# {'id': '118-Republican-St,-Seattle,-WA-98109', 'formattedAddress': '118 Republican St, Seattle, WA 98109', 'addressLine1': '118 Republican St', 'addressLine2': None, 'city': 'Seattle', 'state': 'WA', 'zipCode': '98109', 'county': 'King', 'latitude': 47.62369, 'longitude': -122.35478, 'propertyType': 'Apartment', 'yearBuilt': 2012}
# {'id': '170-11th-Ave,-Seattle,-WA-98122', 'formattedAddress': '170 11th Ave, Seattle, WA 98122', 'addressLine1': '170 11th Ave', 'addressLine2': None, 'city': 'Seattle', 'state': 'WA', 'zipCode': '98122', 'county': 'King', 'latitude': 47.603352, 'longitude': -122.317726, 'propertyType': 'Apartment', 'bedrooms': 1, 'bathrooms': 1, 'yearBuilt': 1901}
# {'id': '1255-Harrison-St,-Seattle,-WA-98109', 'formattedAddress': '1255 Harrison St, Seattle, WA 98109', 'addressLine1': '1255 Harrison St', 'addressLine2': None, 'city': 'Seattle', 'state': 'WA', 'zipCode': '98109', 'county': 'King', 'latitude': 47.621605, 'longitude': -122.331131, 'propertyType': 'Apartment', 'yearBuilt': 2018}
# {'id': '2237-N-106th-St,-Seattle,-WA-98133', 'formattedAddress': '2237 N 106th St, Seattle, WA 98133', 'addressLine1': '2237 N 106th St', 'addressLine2': None, 'city': 'Seattle', 'state': 'WA', 'zipCode': '98133', 'county': 'King', 'latitude': 47.705418, 'longitude': -122.331032, 'propertyType': 'Apartment', 'bedrooms': 1, 'bathrooms': 1, 'yearBuilt': 1985}
# {'id': '1414-10th-Ave,-Seattle,-WA-98122', 'formattedAddress': '1414 10th Ave, Seattle, WA 98122', 'addressLine1': '1414 10th Ave', 'addressLine2': None, 'city': 'Seattle', 'state': 'WA', 'zipCode': '98122', 'county': 'King', 'latitude': 47.61328, 'longitude': -122.31879, 'propertyType': 'Apartment', 'yearBuilt': 2015}
# {'id': '103-12th-Ave,-Seattle,-WA-98122', 'formattedAddress': '103 12th Ave, Seattle, WA 98122', 'addressLine1': '103 12th Ave', 'addressLine2': None, 'city': 'Seattle', 'state': 'WA', 'zipCode': '98122', 'county': 'King County', 'latitude': 47.601853, 'longitude': -122.317195, 'propertyType': 'Apartment', 'yearBuilt': 2015}
# {'id': '4726-11th-Ave-NE,-Seattle,-WA-98105', 'formattedAddress': '4726 11th Ave NE, Seattle, WA 98105', 'addressLine1': '4726 11th Ave NE', 'addressLine2': None, 'city': 'Seattle', 'state': 'WA', 'zipCode': '98105', 'county': 'King', 'latitude': 47.663897, 'longitude': -122.316023, 'propertyType': 'Apartment', 'bedrooms': 2, 'bathrooms': 2, 'yearBuilt': 2001}
# {'id': '829-Ne-67th-St,-Seattle,-WA-98115', 'formattedAddress': '829 Ne 67th St, Seattle, WA 98115', 'addressLine1': '829 Ne 67th St', 'addressLine2': None, 'city': 'Seattle', 'state': 'WA', 'zipCode': '98115', 'county': 'King', 'latitude': 47.677086, 'longitude': -122.31881, 'propertyType': 'Apartment', 'bedrooms': 0, 'bathrooms': 1, 'yearBuilt': 2019}
# {'id': '3801-Stone-Way-N,-Seattle,-WA-98103', 'formattedAddress': '3801 Stone Way N, Seattle, WA 98103', 'addressLine1': '3801 Stone Way N', 'addressLine2': None, 'city': 'Seattle', 'state': 'WA', 'zipCode': '98103', 'county': 'King', 'latitude': 47.65299, 'longitude': -122.343036, 'propertyType': 'Apartment', 'yearBuilt': 2016}
# {'id': '910-John-St,-Seattle,-WA-98109', 'formattedAddress': '910 John St, Seattle, WA 98109', 'addressLine1': '910 John St', 'addressLine2': None, 'city': 'Seattle', 'state': 'WA', 'zipCode': '98109', 'county': 'King', 'latitude': 47.619911, 'longitude': -122.339386, 'propertyType': 'Apartment', 'bathrooms': 2, 'yearBuilt': 2018}
# {'id': '229-Queen-Anne-Ave-N,-Seattle,-WA-98109', 'formattedAddress': '229 Queen Anne Ave N, Seattle, WA 98109', 'addressLine1': '229 Queen Anne Ave N', 'addressLine2': None, 'city': 'Seattle', 'state': 'WA', 'zipCode': '98109', 'county': 'King', 'latitude': 47.620687, 'longitude': -122.357117, 'propertyType': 'Apartment', 'bedrooms': 2, 'bathrooms': 2, 'squareFootage': 1123, 'yearBuilt': 2004}
# {'id': '8551-Greenwood-Ave-N,-Seattle,-WA-98103', 'formattedAddress': '8551 Greenwood Ave N, Seattle, WA 98103', 'addressLine1': '8551 Greenwood Ave N', 'addressLine2': None, 'city': 'Seattle', 'state': 'WA', 'zipCode': '98103', 'county': 'King', 'latitude': 47.692089, 'longitude': -122.355721, 'propertyType': 'Apartment', 'bedrooms': 0, 'bathrooms': 1, 'yearBuilt': 2001}
# {'id': '3800-Aurora-Ave-N,-Seattle,-WA-98103', 'formattedAddress': '3800 Aurora Ave N, Seattle, WA 98103', 'addressLine1': '3800 Aurora Ave N', 'addressLine2': None, 'city': 'Seattle', 'state': 'WA', 'zipCode': '98103', 'county': 'King County', 'latitude': 47.65306, 'longitude': -122.346899, 'propertyType': 'Apartment', 'bedrooms': 1, 'bathrooms': 1, 'yearBuilt': 1994}
# {'id': '905-Dexter-Ave-N,-Seattle,-WA-98109', 'formattedAddress': '905 Dexter Ave N, Seattle, WA 98109', 'addressLine1': '905 Dexter Ave N', 'addressLine2': None, 'city': 'Seattle', 'state': 'WA', 'zipCode': '98109', 'county': 'King', 'latitude': 47.62772, 'longitude': -122.34271, 'propertyType': 'Apartment', 'yearBuilt': 2013}
# {'id': '1942-Westlake-Ave,-Apt-1942,-Seattle,-WA-98101', 'formattedAddress': '1942 Westlake Ave, Apt 1942, Seattle, WA 98101', 'addressLine1': '1942 Westlake Ave', 'addressLine2': 'Apt 1942', 'city': 'Seattle', 'state': 'WA', 'zipCode': '98101', 'county': 'King County', 'latitude': 47.61459, 'longitude': -122.33718, 'propertyType': 'Apartment', 'bedrooms': 1, 'bathrooms': 1, 'yearBuilt': 2001}
# {'id': '915-E-Spruce-St,-Seattle,-WA-98104', 'formattedAddress': '915 E Spruce St, Seattle, WA 98104', 'addressLine1': '915 E Spruce St', 'addressLine2': None, 'city': 'Seattle', 'state': 'WA', 'zipCode': '98104', 'county': 'King County', 'latitude': 47.60318, 'longitude': -122.31974, 'propertyType': 'Apartment', 'bathrooms': 1, 'yearBuilt': 2019}
# {'id': '241-Yale-Ave-N,-Seattle,-WA-98109', 'formattedAddress': '241 Yale Ave N, Seattle, WA 98109', 'addressLine1': '241 Yale Ave N', 'addressLine2': None, 'city': 'Seattle', 'state': 'WA', 'zipCode': '98109', 'county': 'King', 'latitude': 47.62051, 'longitude': -122.33135, 'propertyType': 'Apartment', 'bedrooms': 2, 'bathrooms': 1, 'squareFootage': 556, 'yearBuilt': 2006}
# {'id': '3520-27th-Pl-W,-Seattle,-WA-98199', 'formattedAddress': '3520 27th Pl W, Seattle, WA 98199', 'addressLine1': '3520 27th Pl W', 'addressLine2': None, 'city': 'Seattle', 'state': 'WA', 'zipCode': '98199', 'county': 'King', 'latitude': 47.65261, 'longitude': -122.39029, 'propertyType': 'Apartment', 'yearBuilt': 1975, 'features': {'unitCount': 337}}
# {'id': '2401-3rd-Ave,-Seattle,-WA-98121', 'formattedAddress': '2401 3rd Ave, Seattle, WA 98121', 'addressLine1': '2401 3rd Ave', 'addressLine2': None, 'city': 'Seattle', 'state': 'WA', 'zipCode': '98121', 'county': 'King', 'latitude': 47.61546, 'longitude': -122.34658, 'propertyType': 'Apartment', 'bedrooms': 1, 'bathrooms': 1, 'yearBuilt': 2018}
# {'id': '1425-Spring-St,-Seattle,-WA-98104', 'formattedAddress': '1425 Spring St, Seattle, WA 98104', 'addressLine1': '1425 Spring St', 'addressLine2': None, 'city': 'Seattle', 'state': 'WA', 'zipCode': '98104', 'county': 'King', 'latitude': 47.61143, 'longitude': -122.32122, 'propertyType': 'Apartment', 'bedrooms': 3, 'bathrooms': 3, 'squareFootage': 1801, 'yearBuilt': 2018}
# {'id': '4555-39th-Ave-SW,-Seattle,-WA-98116', 'formattedAddress': '4555 39th Ave SW, Seattle, WA 98116', 'addressLine1': '4555 39th Ave SW', 'addressLine2': None, 'city': 'Seattle', 'state': 'WA', 'zipCode': '98116', 'county': 'King', 'latitude': 47.56137, 'longitude': -122.38232, 'propertyType': 'Apartment', 'bedrooms': 1, 'bathrooms': 1, 'yearBuilt': 2015, 'features': {'unitCount': 216}}
# {'id': '4710-20th-Ave-NE,-Seattle,-WA-98105', 'formattedAddress': '4710 20th Ave NE, Seattle, WA 98105', 'addressLine1': '4710 20th Ave NE', 'addressLine2': None, 'city': 'Seattle', 'state': 'WA', 'zipCode': '98105', 'county': 'King', 'latitude': 47.663548, 'longitude': -122.306188, 'propertyType': 'Apartment', 'bedrooms': 0, 'bathrooms': 1, 'squareFootage': 350, 'yearBuilt': 2020, 'taxAssessments': {'2014': {'year': 2014, 'value': 1042000, 'land': 777000, 'improvements': 265000}, '2015': {'year': 2015, 'value': 1223000, 'land': 911000, 'improvements': 312000}, '2016': {'year': 2016, 'value': 1228000, 'land': 1227000, 'improvements': 1000}, '2017': {'year': 2017, 'value': 1503000, 'land': 1503000, 'improvements': None}, '2018': {'year': 2018, 'value': 1681000, 'land': 1681000, 'improvements': None}, '2019': {'year': 2019, 'value': 1681000, 'land': 1681000, 'improvements': None}, '2020': {'year': 2020, 'value': 9397400, 'land': 1862700, 'improvements': 7534700}, '2021': {'year': 2021, 'value': 12427000, 'land': 2370700, 'improvements': 10056300}, '2022': {'year': 2022, 'value': 11792000, 'land': 2370700, 'improvements': 9421300}, '2023': {'year': 2023, 'value': 12246000, 'land': 2370700, 'improvements': 9875300}}, 'propertyTaxes': {'2014': {'year': 2014, 'total': 11134}, '2015': {'year': 2015, 'total': 11798}, '2016': {'year': 2016, 'total': 12152}, '2017': {'year': 2017, 'total': 14567}, '2018': {'year': 2018, 'total': 16808}, '2019': {'year': 2019, 'total': 14670}, '2020': {'year': 2020, 'total': 87578}, '2021': {'year': 2021, 'total': 116617}, '2022': {'year': 2022, 'total': 105089}, '2023': {'year': 2023, 'total': 100454}}}
# {'id': '4040-8th-Ave-NE,-Seattle,-WA-98105', 'formattedAddress': '4040 8th Ave NE, Seattle, WA 98105', 'addressLine1': '4040 8th Ave NE', 'addressLine2': None, 'city': 'Seattle', 'state': 'WA', 'zipCode': '98105', 'county': 'King', 'latitude': 47.656784, 'longitude': -122.31945, 'propertyType': 'Apartment', 'bedrooms': 1, 'bathrooms': 1, 'yearBuilt': 1967}
# {'id': '206-5th-Ave-N,-Seattle,-WA-98109', 'formattedAddress': '206 5th Ave N, Seattle, WA 98109', 'addressLine1': '206 5th Ave N', 'addressLine2': None, 'city': 'Seattle', 'state': 'WA', 'zipCode': '98109', 'county': 'King', 'latitude': 47.62004, 'longitude': -122.34724, 'propertyType': 'Single Family', 'bedrooms': 1, 'bathrooms': 1, 'squareFootage': 804, 'yearBuilt': 2014}
# {'id': '13433-Greenwood-Ave-N,-Seattle,-WA-98133', 'formattedAddress': '13433 Greenwood Ave N, Seattle, WA 98133', 'addressLine1': '13433 Greenwood Ave N', 'addressLine2': None, 'city': 'Seattle', 'state': 'WA', 'zipCode': '98133', 'county': 'King', 'latitude': 47.726868, 'longitude': -122.356071, 'propertyType': 'Apartment', 'bedrooms': 1, 'bathrooms': 1, 'yearBuilt': 1967}
# {'id': '1111-E-Olive-St,-Seattle,-WA-98122', 'formattedAddress': '1111 E Olive St, Seattle, WA 98122', 'addressLine1': '1111 E Olive St', 'addressLine2': None, 'city': 'Seattle', 'state': 'WA', 'zipCode': '98122', 'county': 'King', 'latitude': 47.616173, 'longitude': -122.317787, 'propertyType': 'Apartment', 'bedrooms': 1, 'bathrooms': 1, 'yearBuilt': 2018}
# {'id': '1280-Harrison-St,-Seattle,-WA-98109', 'formattedAddress': '1280 Harrison St, Seattle, WA 98109', 'addressLine1': '1280 Harrison St', 'addressLine2': None, 'city': 'Seattle', 'state': 'WA', 'zipCode': '98109', 'county': 'King', 'latitude': 47.6228, 'longitude': -122.33123, 'propertyType': 'Apartment', 'bedrooms': 3, 'bathrooms': 2, 'squareFootage': 1296, 'yearBuilt': 2013}
#
# Fetching properties for Phoenix, AZ...
# {'id': '1320-E-Highland-Ave,-Phoenix,-AZ-85014', 'formattedAddress': '1320 E Highland Ave, Phoenix, AZ 85014', 'addressLine1': '1320 E Highland Ave', 'addressLine2': None, 'city': 'Phoenix', 'state': 'AZ', 'zipCode': '85014', 'county': 'Maricopa', 'latitude': 33.50594, 'longitude': -112.05388, 'propertyType': 'Apartment', 'bedrooms': 2, 'bathrooms': 1, 'yearBuilt': 1968}
# {'id': '35035-N-North-Valley-Pkwy,-Phoenix,-AZ-85086', 'formattedAddress': '35035 N North Valley Pkwy, Phoenix, AZ 85086', 'addressLine1': '35035 N North Valley Pkwy', 'addressLine2': None, 'city': 'Phoenix', 'state': 'AZ', 'zipCode': '85086', 'county': 'Maricopa', 'latitude': 33.80303, 'longitude': -112.13114, 'propertyType': 'Apartment', 'yearBuilt': 2018}
# {'id': '3802-N-28th-St,-Phoenix,-AZ-85016', 'formattedAddress': '3802 N 28th St, Phoenix, AZ 85016', 'addressLine1': '3802 N 28th St', 'addressLine2': None, 'city': 'Phoenix', 'state': 'AZ', 'zipCode': '85016', 'county': 'Maricopa', 'latitude': 33.49177, 'longitude': -112.02178, 'propertyType': 'Apartment', 'yearBuilt': 1969}
# {'id': '4815-E-Thomas-Rd,-Phoenix,-AZ-85018', 'formattedAddress': '4815 E Thomas Rd, Phoenix, AZ 85018', 'addressLine1': '4815 E Thomas Rd', 'addressLine2': None, 'city': 'Phoenix', 'state': 'AZ', 'zipCode': '85018', 'county': 'Maricopa', 'latitude': 33.47952, 'longitude': -111.9774, 'propertyType': 'Apartment', 'bedrooms': 0, 'bathrooms': 1, 'squareFootage': 312, 'yearBuilt': 1978}
# {'id': '9330-W-Mcdowell-Rd,-Phoenix,-AZ-85037', 'formattedAddress': '9330 W Mcdowell Rd, Phoenix, AZ 85037', 'addressLine1': '9330 W Mcdowell Rd', 'addressLine2': None, 'city': 'Phoenix', 'state': 'AZ', 'zipCode': '85037', 'county': 'Maricopa County', 'latitude': 33.466446, 'longitude': -112.259655, 'propertyType': 'Apartment', 'yearBuilt': 2002}
# {'id': '5421-W-Indian-School-Rd,-Phoenix,-AZ-85031', 'formattedAddress': '5421 W Indian School Rd, Phoenix, AZ 85031', 'addressLine1': '5421 W Indian School Rd', 'addressLine2': None, 'city': 'Phoenix', 'state': 'AZ', 'zipCode': '85031', 'county': 'Maricopa', 'latitude': 33.493667, 'longitude': -112.176221, 'propertyType': 'Apartment', 'bathrooms': 2, 'yearBuilt': 2001}
# {'id': '5550-E-Deer-Valley-Dr,-Phoenix,-AZ-85054', 'formattedAddress': '5550 E Deer Valley Dr, Phoenix, AZ 85054', 'addressLine1': '5550 E Deer Valley Dr', 'addressLine2': None, 'city': 'Phoenix', 'state': 'AZ', 'zipCode': '85054', 'county': 'Maricopa', 'latitude': 33.677541, 'longitude': -111.961572, 'propertyType': 'Apartment', 'yearBuilt': 2019}
# {'id': '4029-W-Mcdowell-Rd,-Phoenix,-AZ-85009', 'formattedAddress': '4029 W Mcdowell Rd, Phoenix, AZ 85009', 'addressLine1': '4029 W Mcdowell Rd', 'addressLine2': None, 'city': 'Phoenix', 'state': 'AZ', 'zipCode': '85009', 'county': 'Maricopa County', 'latitude': 33.4656, 'longitude': -112.147008, 'propertyType': 'Apartment', 'bedrooms': 2, 'bathrooms': 1, 'yearBuilt': 1968}
# {'id': '6525-N-15th-Ave,-Phoenix,-AZ-85015', 'formattedAddress': '6525 N 15th Ave, Phoenix, AZ 85015', 'addressLine1': '6525 N 15th Ave', 'addressLine2': None, 'city': 'Phoenix', 'state': 'AZ', 'zipCode': '85015', 'county': 'Maricopa County', 'latitude': 33.53223, 'longitude': -112.09055, 'propertyType': 'Apartment', 'bedrooms': 2, 'bathrooms': 2, 'squareFootage': 866}
# {'id': '121-W-Portland-St,-Phoenix,-AZ-85003', 'formattedAddress': '121 W Portland St, Phoenix, AZ 85003', 'addressLine1': '121 W Portland St', 'addressLine2': None, 'city': 'Phoenix', 'state': 'AZ', 'zipCode': '85003', 'county': 'Maricopa', 'latitude': 33.45948, 'longitude': -112.07494, 'propertyType': 'Apartment', 'bathrooms': 1, 'yearBuilt': 1998}
# {'id': '888-N-4th-St,-Phoenix,-AZ-85004', 'formattedAddress': '888 N 4th St, Phoenix, AZ 85004', 'addressLine1': '888 N 4th St', 'addressLine2': None, 'city': 'Phoenix', 'state': 'AZ', 'zipCode': '85004', 'county': 'Maricopa', 'latitude': 33.4571, 'longitude': -112.06901, 'propertyType': 'Apartment', 'bedrooms': 3, 'bathrooms': 3}
# {'id': '6131-N-27th-Ave,-Phoenix,-AZ-85017', 'formattedAddress': '6131 N 27th Ave, Phoenix, AZ 85017', 'addressLine1': '6131 N 27th Ave', 'addressLine2': None, 'city': 'Phoenix', 'state': 'AZ', 'zipCode': '85017', 'county': 'Maricopa', 'latitude': 33.52718, 'longitude': -112.11547, 'propertyType': 'Apartment', 'yearBuilt': 1984, 'features': {'unitCount': 260}}
# {'id': '2242-2302-E-Pinchot-Ave,-Phoenix,-AZ-85016', 'formattedAddress': '2242-2302 E Pinchot Ave, Phoenix, AZ 85016', 'addressLine1': '2242-2302 E Pinchot Ave', 'addressLine2': None, 'city': 'Phoenix', 'state': 'AZ', 'zipCode': '85016', 'county': 'Maricopa County', 'latitude': 33.48236, 'longitude': -112.03252, 'propertyType': 'Apartment', 'bedrooms': 2, 'bathrooms': 1, 'yearBuilt': 1967}
# {'id': '34000-N-27th-Dr,-Phoenix,-AZ-85085', 'formattedAddress': '34000 N 27th Dr, Phoenix, AZ 85085', 'addressLine1': '34000 N 27th Dr', 'addressLine2': None, 'city': 'Phoenix', 'state': 'AZ', 'zipCode': '85085', 'county': 'Maricopa', 'latitude': 33.792764, 'longitude': -112.120852, 'propertyType': 'Apartment', 'bedrooms': 2, 'bathrooms': 2, 'squareFootage': 1208}
# {'id': '3535-W-Tierra-Buena-Ln,-Phoenix,-AZ-85053', 'formattedAddress': '3535 W Tierra Buena Ln, Phoenix, AZ 85053', 'addressLine1': '3535 W Tierra Buena Ln', 'addressLine2': None, 'city': 'Phoenix', 'state': 'AZ', 'zipCode': '85053', 'county': 'Maricopa', 'latitude': 33.6277, 'longitude': -112.13703, 'propertyType': 'Apartment', 'yearBuilt': 1985}
# {'id': '2216-E-Eugie-Ter,-Apt-205,-Phoenix,-AZ-85022', 'formattedAddress': '2216 E Eugie Ter, Apt 205, Phoenix, AZ 85022', 'addressLine1': '2216 E Eugie Ter', 'addressLine2': 'Apt 205', 'city': 'Phoenix', 'state': 'AZ', 'zipCode': '85022', 'county': 'Maricopa', 'latitude': 33.609425, 'longitude': -112.035241, 'propertyType': 'Apartment', 'bedrooms': 1, 'bathrooms': 1, 'squareFootage': 560}
# {'id': '27-E-Corona-Ave,-Phoenix,-AZ-85040', 'formattedAddress': '27 E Corona Ave, Phoenix, AZ 85040', 'addressLine1': '27 E Corona Ave', 'addressLine2': None, 'city': 'Phoenix', 'state': 'AZ', 'zipCode': '85040', 'county': 'Maricopa', 'latitude': 33.40539, 'longitude': -112.07184, 'propertyType': 'Apartment', 'bedrooms': 2, 'bathrooms': 1}
# {'id': '5102-E-Piedmont-Rd,-Phoenix,-AZ-85044', 'formattedAddress': '5102 E Piedmont Rd, Phoenix, AZ 85044', 'addressLine1': '5102 E Piedmont Rd', 'addressLine2': None, 'city': 'Phoenix', 'state': 'AZ', 'zipCode': '85044', 'county': 'Maricopa', 'latitude': 33.358391, 'longitude': -111.972488, 'propertyType': 'Townhouse', 'bedrooms': 2, 'bathrooms': 2, 'lotSize': 374616, 'yearBuilt': 1997}
# {'id': '909-E-Camelback-Rd,-Phoenix,-AZ-85014', 'formattedAddress': '909 E Camelback Rd, Phoenix, AZ 85014', 'addressLine1': '909 E Camelback Rd', 'addressLine2': None, 'city': 'Phoenix', 'state': 'AZ', 'zipCode': '85014', 'county': 'Maricopa', 'latitude': 33.507651, 'longitude': -112.061855, 'propertyType': 'Apartment', 'bedrooms': 1, 'bathrooms': 1, 'squareFootage': 733, 'yearBuilt': 2002}
# {'id': '15202-N-40th-St,-Phoenix,-AZ-85032', 'formattedAddress': '15202 N 40th St, Phoenix, AZ 85032', 'addressLine1': '15202 N 40th St', 'addressLine2': None, 'city': 'Phoenix', 'state': 'AZ', 'zipCode': '85032', 'county': 'Maricopa', 'latitude': 33.62497, 'longitude': -111.99666, 'propertyType': 'Apartment', 'bedrooms': 2, 'bathrooms': 2, 'yearBuilt': 1986}
# {'id': '1450-E-Bell-Rd,-Phoenix,-AZ-85022', 'formattedAddress': '1450 E Bell Rd, Phoenix, AZ 85022', 'addressLine1': '1450 E Bell Rd', 'addressLine2': None, 'city': 'Phoenix', 'state': 'AZ', 'zipCode': '85022', 'county': 'Maricopa', 'latitude': 33.64104, 'longitude': -112.05158, 'propertyType': 'Apartment', 'yearBuilt': 1984}
# {'id': '5401-E-Thomas-Rd,-Phoenix,-AZ-85018', 'formattedAddress': '5401 E Thomas Rd, Phoenix, AZ 85018', 'addressLine1': '5401 E Thomas Rd', 'addressLine2': None, 'city': 'Phoenix', 'state': 'AZ', 'zipCode': '85018', 'county': 'Maricopa', 'latitude': 33.47984, 'longitude': -111.96469, 'propertyType': 'Apartment', 'bedrooms': 1, 'bathrooms': 1, 'squareFootage': 548, 'yearBuilt': 1979}
# {'id': '4323-N-27th-Ave,-Phoenix,-AZ-85017', 'formattedAddress': '4323 N 27th Ave, Phoenix, AZ 85017', 'addressLine1': '4323 N 27th Ave', 'addressLine2': None, 'city': 'Phoenix', 'state': 'AZ', 'zipCode': '85017', 'county': 'Maricopa', 'latitude': 33.499731, 'longitude': -112.115804, 'propertyType': 'Apartment', 'bathrooms': 1}
# ...
# {'id': '57-Nw-69th-St,-Miami,-FL-33150', 'formattedAddress': '57 Nw 69th St, Miami, FL 33150', 'addressLine1': '57 Nw 69th St', 'addressLine2': None, 'city': 'Miami', 'state': 'FL', 'zipCode': '33150', 'county': 'Miami-Dade', 'latitude': 25.83844, 'longitude': -80.197784, 'propertyType': 'Single Family', 'bedrooms': 1, 'bathrooms': 1, 'squareFootage': 620}
# {'id': '851-Ne-1st-Ave,-Unit-511,-Miami,-FL-33132', 'formattedAddress': '851 Ne 1st Ave, Unit 511, Miami, FL 33132', 'addressLine1': '851 Ne 1st Ave', 'addressLine2': 'Unit 511', 'city': 'Miami', 'state': 'FL', 'zipCode': '33132', 'county': 'Miami-Dade', 'latitude': 25.782889, 'longitude': -80.191906, 'propertyType': 'Condo', 'bedrooms': 2, 'bathrooms': 2, 'squareFootage': 1101, 'yearBuilt': 2019, 'hoa': {'fee': 1592}}
# {'id': '13800-Ne-6th-Ave,-North,-Miami,-FL-33161', 'formattedAddress': '13800 Ne 6th Ave, North, Miami, FL 33161', 'addressLine1': '13800 Ne 6th Ave', 'addressLine2': 'North', 'city': 'Miami', 'state': 'FL', 'zipCode': '33161', 'county': 'Miami-Dade', 'latitude': 25.90244, 'longitude': -80.18745, 'propertyType': 'Apartment', 'bedrooms': 2, 'bathrooms': 1, 'yearBuilt': 1962}
# {'id': '14148-Sw-93rd-Ln,-Unit-14148,-Miami,-FL-33186', 'formattedAddress': '14148 Sw 93rd Ln, Unit 14148, Miami, FL 33186', 'addressLine1': '14148 Sw 93rd Ln', 'addressLine2': 'Unit 14148', 'city': 'Miami', 'state': 'FL', 'zipCode': '33186', 'county': 'Miami-Dade', 'latitude': 25.681053, 'longitude': -80.419631, 'propertyType': 'Condo', 'bedrooms': 1, 'bathrooms': 1, 'squareFootage': 862, 'yearBuilt': 1987}
# {'id': '9051-Sw-122nd-Ave,-Miami,-FL-33186', 'formattedAddress': '9051 Sw 122nd Ave, Miami, FL 33186', 'addressLine1': '9051 Sw 122nd Ave', 'addressLine2': None, 'city': 'Miami', 'state': 'FL', 'zipCode': '33186', 'county': 'Miami-Dade', 'latitude': 25.68295, 'longitude': -80.3908, 'propertyType': 'Apartment', 'yearBuilt': 1992}
# {'id': '8818-Sw-72nd-St,-Miami,-FL-33173', 'formattedAddress': '8818 Sw 72nd St, Miami, FL 33173', 'addressLine1': '8818 Sw 72nd St', 'addressLine2': None, 'city': 'Miami', 'state': 'FL', 'zipCode': '33173', 'county': 'Miami-Dade County', 'latitude': 25.70124, 'longitude': -80.33694, 'propertyType': 'Apartment', 'yearBuilt': 1969}
# {'id': '50-Sw-10th-St,-Miami,-FL-33130', 'formattedAddress': '50 Sw 10th St, Miami, FL 33130', 'addressLine1': '50 Sw 10th St', 'addressLine2': None, 'city': 'Miami', 'state': 'FL', 'zipCode': '33130', 'county': 'Miami-Dade', 'latitude': 25.76395, 'longitude': -80.19387, 'propertyType': 'Apartment', 'bedrooms': 1, 'bathrooms': 1, 'yearBuilt': 2002}
# {'id': '9117-Sw-72nd-Ave,-Miami,-FL-33156', 'formattedAddress': '9117 Sw 72nd Ave, Miami, FL 33156', 'addressLine1': '9117 Sw 72nd Ave', 'addressLine2': None, 'city': 'Miami', 'state': 'FL', 'zipCode': '33156', 'county': 'Miami-Dade County', 'latitude': 25.68613, 'longitude': -80.309841, 'propertyType': 'Apartment', 'bedrooms': 1, 'bathrooms': 1, 'yearBuilt': 1966}
# {'id': '8961-9041-Sw-142nd-Ave,-Miami,-FL-33186', 'formattedAddress': '8961-9041 Sw 142nd Ave, Miami, FL 33186', 'addressLine1': '8961-9041 Sw 142nd Ave', 'addressLine2': None, 'city': 'Miami', 'state': 'FL', 'zipCode': '33186', 'county': 'Miami-Dade County', 'latitude': 25.68428, 'longitude': -80.42268, 'propertyType': 'Apartment', 'yearBuilt': 1986}
# {'id': '9300-Sw-137th-Ave,-Miami,-FL-33186', 'formattedAddress': '9300 Sw 137th Ave, Miami, FL 33186', 'addressLine1': '9300 Sw 137th Ave', 'addressLine2': None, 'city': 'Miami', 'state': 'FL', 'zipCode': '33186', 'county': 'Miami-Dade', 'latitude': 25.68107, 'longitude': -80.41742, 'propertyType': 'Apartment', 'bedrooms': 1, 'bathrooms': 1, 'yearBuilt': 1988}
# {'id': '2201-Ludlam-Rd,-Miami,-FL-33155', 'formattedAddress': '2201 Ludlam Rd, Miami, FL 33155', 'addressLine1': '2201 Ludlam Rd', 'addressLine2': None, 'city': 'Miami', 'state': 'FL', 'zipCode': '33155', 'county': 'Miami-Dade County', 'latitude': 25.74956, 'longitude': -80.303418, 'propertyType': 'Apartment', 'bedrooms': 2, 'bathrooms': 2, 'squareFootage': 1000, 'yearBuilt': 2019}
# {'id': '8855-Fontainebleau-Blvd,-Miami,-FL-33172', 'formattedAddress': '8855 Fontainebleau Blvd, Miami, FL 33172', 'addressLine1': '8855 Fontainebleau Blvd', 'addressLine2': None, 'city': 'Miami', 'state': 'FL', 'zipCode': '33172', 'county': 'Miami-Dade', 'latitude': 25.7732, 'longitude': -80.340149, 'propertyType': 'Apartment', 'yearBuilt': 1971}
# {'id': '13865-W-Dixie-Hwy,-North,-Miami,-FL-33161', 'formattedAddress': '13865 W Dixie Hwy, North, Miami, FL 33161', 'addressLine1': '13865 W Dixie Hwy', 'addressLine2': 'North', 'city': 'Miami', 'state': 'FL', 'zipCode': '33161', 'county': 'Miami-Dade County', 'latitude': 25.90202, 'longitude': -80.17576, 'propertyType': 'Apartment', 'yearBuilt': 1969}
# {'id': '8215-Sw-72nd-Ave,-Miami,-FL-33143', 'formattedAddress': '8215 Sw 72nd Ave, Miami, FL 33143', 'addressLine1': '8215 Sw 72nd Ave', 'addressLine2': None, 'city': 'Miami', 'state': 'FL', 'zipCode': '33143', 'county': 'Miami-Dade', 'latitude': 25.693701, 'longitude': -80.30854, 'propertyType': 'Apartment', 'bedrooms': 2, 'bathrooms': 2, 'squareFootage': 1104, 'yearBuilt': 2017}
# {'id': '340-W-Flagler-St,-Miami,-FL-33130', 'formattedAddress': '340 W Flagler St, Miami, FL 33130', 'addressLine1': '340 W Flagler St', 'addressLine2': None, 'city': 'Miami', 'state': 'FL', 'zipCode': '33130', 'county': 'Miami-Dade', 'latitude': 25.773568, 'longitude': -80.199961, 'propertyType': 'Apartment', 'bedrooms': 1, 'bathrooms': 1, 'squareFootage': 764}
# {'id': '6880-6920-Sw-44th-St,-Miami,-FL-33155', 'formattedAddress': '6880-6920 Sw 44th St, Miami, FL 33155', 'addressLine1': '6880-6920 Sw 44th St', 'addressLine2': None, 'city': 'Miami', 'state': 'FL', 'zipCode': '33155', 'county': 'Miami-Dade County', 'latitude': 25.72908, 'longitude': -80.3053, 'propertyType': 'Apartment', 'yearBuilt': 1986}
# {'id': '455-Ne-24th-St,-Miami,-FL-33137', 'formattedAddress': '455 Ne 24th St, Miami, FL 33137', 'addressLine1': '455 Ne 24th St', 'addressLine2': None, 'city': 'Miami', 'state': 'FL', 'zipCode': '33137', 'county': 'Miami-Dade', 'latitude': 25.80044, 'longitude': -80.18698, 'propertyType': 'Apartment', 'bedrooms': 2, 'bathrooms': 2, 'squareFootage': 1109, 'yearBuilt': 2019}
# {'id': '6259-Sunset-Dr,-South,-Miami,-FL-33143', 'formattedAddress': '6259 Sunset Dr, South, Miami, FL 33143', 'addressLine1': '6259 Sunset Dr', 'addressLine2': 'South', 'city': 'Miami', 'state': 'FL', 'zipCode': '33143', 'county': 'Miami-Dade County', 'latitude': 25.70443, 'longitude': -80.294668, 'propertyType': 'Apartment', 'bedrooms': 1, 'bathrooms': 1, 'yearBuilt': 1964}
# {'id': '11020-Sw-196th-St,-Miami,-FL-33157', 'formattedAddress': '11020 Sw 196th St, Miami, FL 33157', 'addressLine1': '11020 Sw 196th St', 'addressLine2': None, 'city': 'Miami', 'state': 'FL', 'zipCode': '33157', 'county': 'Miami-Dade County', 'latitude': 25.583963, 'longitude': -80.369557, 'propertyType': 'Apartment', 'yearBuilt': 1973}
# {'id': '777-Nw-155th-Ln,-Miami,-FL-33169', 'formattedAddress': '777 Nw 155th Ln, Miami, FL 33169', 'addressLine1': '777 Nw 155th Ln', 'addressLine2': None, 'city': 'Miami', 'state': 'FL', 'zipCode': '33169', 'county': 'Miami-Dade County', 'latitude': 25.9178, 'longitude': -80.21404, 'propertyType': 'Apartment', 'bedrooms': 0, 'bathrooms': 1, 'yearBuilt': 1973}
# {'id': '9601-Sw-142nd-Ave,-Miami,-FL-33186', 'formattedAddress': '9601 Sw 142nd Ave, Miami, FL 33186', 'addressLine1': '9601 Sw 142nd Ave', 'addressLine2': None, 'city': 'Miami', 'state': 'FL', 'zipCode': '33186', 'county': 'Miami-Dade County', 'latitude': 25.676114, 'longitude': -80.419706, 'propertyType': 'Apartment', 'bedrooms': 2, 'bathrooms': 2, 'squareFootage': 980, 'yearBuilt': 1986}
# {'id': '230-Ne-4th-St,-Miami,-FL-33132', 'formattedAddress': '230 Ne 4th St, Miami, FL 33132', 'addressLine1': '230 Ne 4th St', 'addressLine2': None, 'city': 'Miami', 'state': 'FL', 'zipCode': '33132', 'county': 'Miami-Dade', 'latitude': 25.777841, 'longitude': -80.189716, 'propertyType': 'Apartment', 'bedrooms': 1, 'bathrooms': 1, 'yearBuilt': 2018}
# {'id': '58-Ne-14th-St,-Miami,-FL-33132', 'formattedAddress': '58 Ne 14th St, Miami, FL 33132', 'addressLine1': '58 Ne 14th St', 'addressLine2': None, 'city': 'Miami', 'state': 'FL', 'zipCode': '33132', 'county': 'Miami-Dade County', 'latitude': 25.787947, 'longitude': -80.192885, 'propertyType': 'Apartment', 'bedrooms': 2, 'bathrooms': 2, 'squareFootage': 1200, 'yearBuilt': 2019}
# {'id': '8337-Sw-107th-Ave,-Miami,-FL-33173', 'formattedAddress': '8337 Sw 107th Ave, Miami, FL 33173', 'addressLine1': '8337 Sw 107th Ave', 'addressLine2': None, 'city': 'Miami', 'state': 'FL', 'zipCode': '33173', 'county': 'Miami-Dade', 'latitude': 25.69122, 'longitude': -80.36561, 'propertyType': 'Apartment', 'yearBuilt': 1976}
# {'id': '1111-Brickell-Bay-Dr,-Miami,-FL-33131', 'formattedAddress': '1111 Brickell Bay Dr, Miami, FL 33131', 'addressLine1': '1111 Brickell Bay Dr', 'addressLine2': None, 'city': 'Miami', 'state': 'FL', 'zipCode': '33131', 'county': 'Miami-Dade', 'latitude': 25.762968, 'longitude': -80.189136, 'propertyType': 'Apartment', 'bedrooms': 2, 'bathrooms': 2, 'squareFootage': 1238, 'yearBuilt': 1998}
# {'id': '86-Sw-8th-St,-Miami,-FL-33130', 'formattedAddress': '86 Sw 8th St, Miami, FL 33130', 'addressLine1': '86 Sw 8th St', 'addressLine2': None, 'city': 'Miami', 'state': 'FL', 'zipCode': '33130', 'county': 'Miami-Dade', 'latitude': 25.766085, 'longitude': -80.194466, 'propertyType': 'Apartment', 'bedrooms': 1, 'bathrooms': 1, 'squareFootage': 783, 'yearBuilt': 2018}
# {'id': '760-Ne-85th-St,-Miami,-FL-33138', 'formattedAddress': '760 Ne 85th St, Miami, FL 33138', 'addressLine1': '760 Ne 85th St', 'addressLine2': None, 'city': 'Miami', 'state': 'FL', 'zipCode': '33138', 'county': 'Miami-Dade', 'latitude': 25.853339, 'longitude': -80.181544, 'propertyType': 'Apartment', 'yearBuilt': 2015}
# {'id': '2660-Sw-37th-Ave,-Miami,-FL-33133', 'formattedAddress': '2660 Sw 37th Ave, Miami, FL 33133', 'addressLine1': '2660 Sw 37th Ave', 'addressLine2': None, 'city': 'Miami', 'state': 'FL', 'zipCode': '33133', 'county': 'Miami-Dade County', 'latitude': 25.74173, 'longitude': -80.254628, 'propertyType': 'Apartment', 'bedrooms': 0, 'bathrooms': 1, 'yearBuilt': 1994}
# {'id': '5375-Nw-7th-St,-Miami,-FL-33126', 'formattedAddress': '5375 Nw 7th St, Miami, FL 33126', 'addressLine1': '5375 Nw 7th St', 'addressLine2': None, 'city': 'Miami', 'state': 'FL', 'zipCode': '33126', 'county': 'Miami-Dade', 'latitude': 25.778509, 'longitude': -80.283279, 'propertyType': 'Apartment', 'bedrooms': 2, 'bathrooms': 2, 'squareFootage': 834, 'yearBuilt': 2019}
# {'id': '11325-Nw-7th-St,-Miami,-FL-33172', 'formattedAddress': '11325 Nw 7th St, Miami, FL 33172', 'addressLine1': '11325 Nw 7th St', 'addressLine2': None, 'city': 'Miami', 'state': 'FL', 'zipCode': '33172', 'county': 'Miami-Dade', 'latitude': 25.77572, 'longitude': -80.37695, 'propertyType': 'Apartment', 'bathrooms': 2, 'yearBuilt': 1980}
# {'id': '6001-Sw-70th-St,-South,-Miami,-FL-33143', 'formattedAddress': '6001 Sw 70th St, South, Miami, FL 33143', 'addressLine1': '6001 Sw 70th St', 'addressLine2': 'South', 'city': 'Miami', 'state': 'FL', 'zipCode': '33143', 'county': 'Miami-Dade', 'latitude': 25.70649, 'longitude': -80.29128, 'propertyType': 'Apartment', 'yearBuilt': 2004}
# {'id': '125-Ne-32nd-St,-Miami,-FL-33137', 'formattedAddress': '125 Ne 32nd St, Miami, FL 33137', 'addressLine1': '125 Ne 32nd St', 'addressLine2': None, 'city': 'Miami', 'state': 'FL', 'zipCode': '33137', 'county': 'Miami-Dade', 'latitude': 25.807001, 'longitude': -80.19249, 'propertyType': 'Apartment', 'bedrooms': 2, 'bathrooms': 2, 'yearBuilt': 2016}
# {'id': '9357-Sw-77th-Ave,-Miami,-FL-33156', 'formattedAddress': '9357 Sw 77th Ave, Miami, FL 33156', 'addressLine1': '9357 Sw 77th Ave', 'addressLine2': None, 'city': 'Miami', 'state': 'FL', 'zipCode': '33156', 'county': 'Miami-Dade', 'latitude': 25.68401, 'longitude': -80.31825, 'propertyType': 'Apartment', 'yearBuilt': 1973}
# {'id': '2321-Laguna-Cir,-North,-Miami,-FL-33181', 'formattedAddress': '2321 Laguna Cir, North, Miami, FL 33181', 'addressLine1': '2321 Laguna Cir', 'addressLine2': 'North', 'city': 'Miami', 'state': 'FL', 'zipCode': '33181', 'county': 'Miami-Dade', 'latitude': 25.912964, 'longitude': -80.152579, 'propertyType': 'Apartment', 'bedrooms': 1, 'bathrooms': 1, 'yearBuilt': 2019}
# {'id': '580-Ne-127th-St,-North,-Miami,-FL-33161', 'formattedAddress': '580 Ne 127th St, North, Miami, FL 33161', 'addressLine1': '580 Ne 127th St', 'addressLine2': 'North', 'city': 'Miami', 'state': 'FL', 'zipCode': '33161', 'county': 'Miami-Dade', 'latitude': 25.891699, 'longitude': -80.187209, 'propertyType': 'Apartment', 'bedrooms': 1, 'bathrooms': 1}
# {'id': '235-Nw-14th-Ter,-Miami,-FL-33136', 'formattedAddress': '235 Nw 14th Ter, Miami, FL 33136', 'addressLine1': '235 Nw 14th Ter', 'addressLine2': None, 'city': 'Miami', 'state': 'FL', 'zipCode': '33136', 'county': 'Miami-Dade', 'latitude': 25.788814, 'longitude': -80.199495, 'propertyType': 'Apartment'}
# {'id': '7440-N-Kendall-Dr,-Miami,-FL-33156', 'formattedAddress': '7440 N Kendall Dr, Miami, FL 33156', 'addressLine1': '7440 N Kendall Dr', 'addressLine2': None, 'city': 'Miami', 'state': 'FL', 'zipCode': '33156', 'county': 'Miami-Dade', 'latitude': 25.687704, 'longitude': -80.31563, 'propertyType': 'Single Family', 'bedrooms': 1, 'bathrooms': 1, 'squareFootage': 545, 'yearBuilt': 2016}
# {'id': '3000-Sw-3rd-Ave,-Miami,-FL-33129', 'formattedAddress': '3000 Sw 3rd Ave, Miami, FL 33129', 'addressLine1': '3000 Sw 3rd Ave', 'addressLine2': None, 'city': 'Miami', 'state': 'FL', 'zipCode': '33129', 'county': 'Miami-Dade', 'latitude': 25.752996, 'longitude': -80.212311, 'propertyType': 'Single Family', 'bedrooms': 1, 'bathrooms': 1, 'yearBuilt': 2000}
# {'id': '6620-Sw-57th-Ave,-Miami,-FL-33143', 'formattedAddress': '6620 Sw 57th Ave, Miami, FL 33143', 'addressLine1': '6620 Sw 57th Ave', 'addressLine2': None, 'city': 'Miami', 'state': 'FL', 'zipCode': '33143', 'county': 'Miami-Dade County', 'latitude': 25.70902, 'longitude': -80.28599, 'propertyType': 'Apartment', 'bathrooms': 2, 'yearBuilt': 2009}
# {'id': '10571-Sw-156th-Pl,-Miami,-FL-33196', 'formattedAddress': '10571 Sw 156th Pl, Miami, FL 33196', 'addressLine1': '10571 Sw 156th Pl', 'addressLine2': None, 'city': 'Miami', 'state': 'FL', 'zipCode': '33196', 'county': 'Miami-Dade', 'latitude': 25.66769, 'longitude': -80.44803, 'propertyType': 'Apartment', 'yearBuilt': 1988}
# {'id': '8940-Nw-8th-St,-Miami,-FL-33172', 'formattedAddress': '8940 Nw 8th St, Miami, FL 33172', 'addressLine1': '8940 Nw 8th St', 'addressLine2': None, 'city': 'Miami', 'state': 'FL', 'zipCode': '33172', 'county': 'Miami-Dade', 'latitude': 25.77947, 'longitude': -80.34076, 'propertyType': 'Apartment', 'yearBuilt': 1974}
# {'id': '12375-Sw-18th-St,-Miami,-FL-33175', 'formattedAddress': '12375 Sw 18th St, Miami, FL 33175', 'addressLine1': '12375 Sw 18th St', 'addressLine2': None, 'city': 'Miami', 'state': 'FL', 'zipCode': '33175', 'county': 'Miami-Dade', 'latitude': 25.753339, 'longitude': -80.395481, 'propertyType': 'Apartment', 'bedrooms': 2, 'bathrooms': 2, 'yearBuilt': 1921}
# {'id': '3967-Ne-168th-St,-Miami,-FL-33160', 'formattedAddress': '3967 Ne 168th St, Miami, FL 33160', 'addressLine1': '3967 Ne 168th St', 'addressLine2': None, 'city': 'Miami', 'state': 'FL', 'zipCode': '33160', 'county': 'Miami-Dade County', 'latitude': 25.935085, 'longitude': -80.131993, 'propertyType': 'Apartment', 'yearBuilt': 1974}
# {'id': '13150-Memorial-Hwy,-North,-Miami,-FL-33161', 'formattedAddress': '13150 Memorial Hwy, North, Miami, FL 33161', 'addressLine1': '13150 Memorial Hwy', 'addressLine2': 'North', 'city': 'Miami', 'state': 'FL', 'zipCode': '33161', 'county': 'Miami-Dade', 'latitude': 25.896132, 'longitude': -80.194298, 'propertyType': 'Apartment', 'bedrooms': 2, 'bathrooms': 1, 'squareFootage': 48053, 'lotSize': 51806, 'yearBuilt': 1967}

# %%
file_name = 'real_estate.json'

with open(file_name, 'w') as file:
    json.dump(all_properties, file, indent=4)

# %%
real_estate_df = pd.read_json('real_estate.json')
real_estate_df.head()
# Out:
#                                         id  \
# 0       7011-W-Parmer-Ln,-Austin,-TX-78729
# 1      5200-N-Lamar-Blvd,-Austin,-TX-78751
# 2          1301-W-5th-St,-Austin,-TX-78703
# 3  1044-Camino-Ln,-Costa,-Austin,-TX-78752
# 4          800-W-38th-St,-Austin,-TX-78705
#
#                           formattedAddress       addressLine1 addressLine2  \
# 0       7011 W Parmer Ln, Austin, TX 78729   7011 W Parmer Ln         None
# 1      5200 N Lamar Blvd, Austin, TX 78751  5200 N Lamar Blvd         None
# 2          1301 W 5th St, Austin, TX 78703      1301 W 5th St         None
# 3  1044 Camino Ln, Costa, Austin, TX 78752     1044 Camino Ln        Costa
# 4          800 W 38th St, Austin, TX 78705      800 W 38th St         None
#
#      city state  zipCode      county   latitude  longitude  ... features  \
# 0  Austin    TX    78729  Williamson  30.450651 -97.749853  ...      NaN
# 1  Austin    TX    78751      Travis  30.320159 -97.731593  ...      NaN
# 2  Austin    TX    78703      Travis  30.271746 -97.759877  ...      NaN
# 3  Austin    TX    78752      Travis  30.325260 -97.699270  ...      NaN
# 4  Austin    TX    78705      Travis  30.304715 -97.741423  ...      NaN
#
#    taxAssessments  propertyTaxes  lotSize  assessorID legalDescription  \
# 0             NaN            NaN      NaN         NaN              NaN
# 1             NaN            NaN      NaN         NaN              NaN
# 2             NaN            NaN      NaN         NaN              NaN
# 3             NaN            NaN      NaN         NaN              NaN
# 4             NaN            NaN      NaN         NaN              NaN
#
#   subdivision owner  ownerOccupied  hoa
# 0         NaN   NaN            NaN  NaN
# 1         NaN   NaN            NaN  NaN
# 2         NaN   NaN            NaN  NaN
# 3         NaN   NaN            NaN  NaN
# 4         NaN   NaN            NaN  NaN
#
# [5 rows x 25 columns]

# %%
real_estate_df.columns
# Out:
# Index(['id', 'formattedAddress', 'addressLine1', 'addressLine2', 'city',
#        'state', 'zipCode', 'county', 'latitude', 'longitude', 'propertyType',
#        'yearBuilt', 'bedrooms', 'bathrooms', 'squareFootage', 'features',
#        'taxAssessments', 'propertyTaxes', 'lotSize', 'assessorID',
#        'legalDescription', 'subdivision', 'owner', 'ownerOccupied', 'hoa'],
#       dtype='object')

# %%
real_estate_df['yearBuilt'] = real_estate_df['yearBuilt'].fillna(1900)
real_estate_df['ownerOccupied'] = real_estate_df['ownerOccupied'].fillna(False)

key_cols = ['propertyType', 'owner', 'formattedAddress']
non_keys = [col for col in real_estate_df.columns if col not in key_cols]
real_estate_df[non_keys] = real_estate_df[non_keys].fillna('Unknown')

# %%
real_estate_df['taxAssessments'] = real_estate_df['taxAssessments'].astype(str)
real_estate_df['propertyTaxes'] = real_estate_df['propertyTaxes'].astype(str)
real_estate_df['assessorID'] = real_estate_df['assessorID'].astype(str)
real_estate_df['legalDescription'] = real_estate_df['legalDescription'].astype(str)
real_estate_df['subdivision'] = real_estate_df['subdivision'].astype(str)
real_estate_df['hoa'] = real_estate_df['hoa'].astype(str)
real_estate_df['formattedAddress'] = real_estate_df['formattedAddress'].astype(str)
real_estate_df['owner'] = real_estate_df['owner'].astype(str)
real_estate_df['propertyType'] = real_estate_df['propertyType'].astype(str)
real_estate_df['addressLine1'] = real_estate_df['addressLine1'].astype(str)
real_estate_df['county'] = real_estate_df['county'].astype(str)
real_estate_df['city'] = real_estate_df['city'].astype(str)
real_estate_df['state'] = real_estate_df['state'].astype(str)

# %%
# Creating the dimension tables

location_dim = real_estate_df[['formattedAddress', 'addressLine1', 'addressLine2', 
                               'county', 'zipCode', 'city', 'state',
                               'latitude', 'longitude']].copy().drop_duplicates().reset_index(drop=True)

location_dim.index.name = 'location_id' # Giving the index column a name.

location_dim = location_dim.reset_index() # Converting the index into a proper/recognized column

# %%
cols_to_check = [
    'propertyType', 'bedrooms', 'bathrooms', 'squareFootage',
    'features', 'lotSize', 'hoa'
]

real_estate_df[cols_to_check] = real_estate_df[cols_to_check].applymap(
    lambda x: json.dumps(x) if isinstance(x, (dict, list)) else str(x)
)

real_estate_df['features'] = real_estate_df['features'].replace(
    ['N/A', 'nan', 'None', '', 'null', 'Unknown'], 'None'
)


features_dim = real_estate_df[cols_to_check].drop_duplicates().reset_index(drop=True)
features_dim.index.name = 'features_id'
features_dim = features_dim.reset_index()

features_dim.replace(
    ['N/A', 'NA', '', 'null', 'Unknown', 'None'], None, inplace=True
)

numeric_cols = ['bedrooms', 'bathrooms', 'squareFootage', 'lotSize']
for col in numeric_cols:
    features_dim[col] = pd.to_numeric(features_dim[col], errors='coerce')

features_dim = features_dim.query(
    'squareFootage < 1000000 and bedrooms < 100 and bathrooms < 100 and lotSize < 1000000'
).copy()

features_dim['features'] = features_dim['features'].apply(
    lambda x: json.dumps(x) if isinstance(x, (dict, list)) else x
)

real_estate_df['bedrooms'] = pd.to_numeric(real_estate_df['bedrooms'], errors='coerce')
real_estate_df['bathrooms'] = pd.to_numeric(real_estate_df['bathrooms'], errors='coerce')
real_estate_df['squareFootage'] = pd.to_numeric(real_estate_df['squareFootage'], errors='coerce')
real_estate_df['lotSize'] = pd.to_numeric(real_estate_df['lotSize'], errors='coerce')

features_dim['bedrooms'] = pd.to_numeric(features_dim['bedrooms'], errors='coerce')
features_dim['bathrooms'] = pd.to_numeric(features_dim['bathrooms'], errors='coerce')
features_dim['squareFootage'] = pd.to_numeric(features_dim['squareFootage'], errors='coerce')
features_dim['lotSize'] = pd.to_numeric(features_dim['lotSize'], errors='coerce')


print(features_dim.dtypes)
print(features_dim.head())
# Out:
# features_id        int64
# propertyType      object
# bedrooms         float64
# bathrooms        float64
# squareFootage    float64
# features          object
# lotSize          float64
# hoa               object
# dtype: object
#     features_id   propertyType  bedrooms  bathrooms  squareFootage features  \
# 8             8      apartment       2.0        2.0          704.0     None
# 58           58  single family       3.0        3.0         1923.0     None
# 76           76      apartment       2.0        2.0        48053.0     None
#
#     lotSize   hoa
# 8   43560.0  None
# 58   5580.0  None
# 76  51806.0  None
# C:\Users\luk\AppData\Local\Temp\ipykernel_20384\834059164.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   real_estate_df[cols_to_check] = real_estate_df[cols_to_check].applymap(

# %%
owner_dim = real_estate_df[['owner']]

owner_dim.index.name = 'owner_id'

owner_dim = owner_dim.reset_index()

# %%
def clean_key_col(df, col):
    df[col] = df[col].astype(str).str.strip().str.lower()
    return df

cols_to_clean = ['propertyType', 'owner', 'formattedAddress']

for col in cols_to_clean:
    real_estate_df = clean_key_col(real_estate_df, col)
    if col in features_dim: features_dim = clean_key_col(features_dim, col)
    if col in owner_dim: owner_dim = clean_key_col(owner_dim, col)
    if col in location_dim: location_dim = clean_key_col(location_dim, col)

# %%
property_fact = real_estate_df.merge(location_dim, on=['formattedAddress', 'addressLine1', 'addressLine2', 
                               'county', 'zipCode', 'city', 'state',
                               'latitude', 'longitude'], how='left') \
                               .merge(features_dim, on=['propertyType', 'bedrooms', 'bathrooms', 'squareFootage', 
                               'features', 'lotSize'], how='left') \
                               .merge(owner_dim, on=['owner'], how='left') \
                               [['id', 'location_id', 'features_id', 'owner_id', 'yearBuilt', 'assessorID', 'taxAssessments', 
                                 'propertyTaxes', 'legalDescription', 'subdivision', 'ownerOccupied']]
                              

property_fact.drop_duplicates(subset=['id', 'location_id', 'features_id', 'owner_id'], keep='last', inplace=True)
property_fact = property_fact[property_fact['location_id'].notnull()].copy()

# %%
property_fact['ownerOccupied'] = property_fact['ownerOccupied'].apply(lambda x: bool(x) if pd.notnull(x) else None)

# %%
location_dim = location_dim.applymap(lambda x: None if pd.isna(x) else x)
features_dim = features_dim.applymap(lambda x: None if pd.isna(x) else x)
owner_dim = owner_dim.applymap(lambda x: None if pd.isna(x) else x)
property_fact = property_fact.applymap(lambda x: None if pd.isna(x) else x)
# Out:
# C:\Users\luk\AppData\Local\Temp\ipykernel_20384\3336098060.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   location_dim = location_dim.applymap(lambda x: None if pd.isna(x) else x)
# C:\Users\luk\AppData\Local\Temp\ipykernel_20384\3336098060.py:2: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   features_dim = features_dim.applymap(lambda x: None if pd.isna(x) else x)
# C:\Users\luk\AppData\Local\Temp\ipykernel_20384\3336098060.py:3: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   owner_dim = owner_dim.applymap(lambda x: None if pd.isna(x) else x)
# C:\Users\luk\AppData\Local\Temp\ipykernel_20384\3336098060.py:4: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   property_fact = property_fact.applymap(lambda x: None if pd.isna(x) else x)

# %%
# Quite a lot of mismatched rows. Storing them here to inspect if they pop up again.

rejected_facts = property_fact[
    property_fact['location_id'].isna() | 
    property_fact['features_id'].isna() | 
    property_fact['owner_id'].isna()
].copy()

# %%
location_dim.to_csv('location_dim.csv', index=False)
features_dim.to_csv('features_dim.csv', index=False)
owner_dim.to_csv('owner_dim.csv', index=False)
property_fact.to_csv('property_fact.csv', index=False)

# %%
def get_db_connection():
    connection = psycopg2.connect(
        host = 'localhost',
        database = 'Zuma_Agency',
        user = 'postgres',
        password = 'MongoDB4luv'
    )
    return connection

# %%
conn = get_db_connection()
cursor = conn.cursor()

for _,row in location_dim.iterrows():
    cursor.execute('''
                        INSERT INTO zuma.location_dim (formattedAddress, addressLine1, addressLine2, 
                                                              county, zipCode, city, state, latitude, longitude)
                        VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s)''',
                   (row['formattedAddress'], row['addressLine1'], row['addressLine2'], row['county'], row['zipCode'], row['city'], 
                    row['state'], row['latitude'], row['longitude'])
        )

for _,row in features_dim.iterrows():
    cursor.execute('''
                        INSERT INTO zuma.features_dim (propertyType, bedrooms, bathrooms, squareFootage, features, lotSize, hoa)
                        VALUES (%s, %s, %s, %s, %s, %s, %s)''',
                   (row['propertyType'], row['bedrooms'], row['bathrooms'], row['squareFootage'], row['features'], 
                    row['lotSize'], row['hoa'])
        )
    
for _,row in owner_dim.iterrows():
    cursor.execute('''
                        INSERT INTO zuma.owner_dim (owner)
                        VALUES (%s)''',
                   (row['owner'],)
        )
    
for _, row in property_fact.iterrows():
    cursor.execute('''
                        INSERT INTO zuma.property_fact (id, yearBuilt, assessorID, taxAssessments,
                                                   propertyTaxes, legalDescription, subdivision, ownerOccupied)
                        VALUES (%s, %s, %s, %s, %s, %s, %s, %s)
                        ON CONFLICT (id) DO NOTHING''', 
                    (row['id'], row['yearBuilt'], row['assessorID'], row['taxAssessments'],
                     row['propertyTaxes'], row['legalDescription'], row['subdivision'], row['ownerOccupied'])
        )


conn.commit()
cursor.close()
conn.close()
